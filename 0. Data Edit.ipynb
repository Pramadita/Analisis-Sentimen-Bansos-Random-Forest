# %%
import numpy as np
import pandas as pd
import nltk 

from datetime import datetime

# %%
data1 = pd.read_csv('Dataset/Label Otomatis/Label 5-20.csv', sep=';')

# %%
def load_data():
    data = pd.concat([data1])
    return data

# %%
tweet_df = load_data()

# %%
tweet_df.head()
# Out:
#             Tanggal      Screen Name               Source Hashtags  \
# 0  05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 1  05/05/2021 00:00       pirmann___  Twitter for Android       []
# 2  05/05/2021 00:01       warnapanci  Twitter for Android       []
# 3  05/05/2021 00:01         riskikky   Twitter for iPhone       []
# 4  05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
#
#   Banyak Retweet                                              Tweet  \
# 0            0 0  halah tidak kaget alat test saja di manipulasi...
# 1         1977 0  menurut keterangan saksi terdakwa pejabat keme...
# 2          442 0  ada kasus 2 besar yang sekarang sedang ditanga...
# 3         1730 0  perusahaan penyedia paket bansos ternyata bany...
# 4          467 0  salah satu kasus besar yang sedang dihadapi ol...
#
#                                             Terjemah  Subjectivity  \
# 0  i'm not surprised that the test tool has been ...      0.483333
# ...

# %%
df  = pd.DataFrame(tweet_df[['Tanggal','Screen Name','Source', 'Hashtags','Banyak Retweet','Tweet', 'Terjemah','Subjectivity','Polarity','Sentiment','Sentiments']])

# %%
df
# Out:
#                Tanggal      Screen Name               Source Hashtags  \
# 0     05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 1     05/05/2021 00:00       pirmann___  Twitter for Android       []
# 2     05/05/2021 00:01       warnapanci  Twitter for Android       []
# 3     05/05/2021 00:01         riskikky   Twitter for iPhone       []
# 4     05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# ...                ...              ...                  ...      ...
# 9163  20/05/2021 16:23     Bams27735590            Instagram       []
# 9164  20/05/2021 16:24       YeshaWally  Twitter for Android       []
# 9165  20/05/2021 16:25       YeshaWally  Twitter for Android       []
# 9166  20/05/2021 16:27  Abiiiii54859988  Twitter for Android       []
# 9167  20/05/2021 16:27         EvaMalca  Twitter for Android       []
#
#      Banyak Retweet                                              Tweet  \
# ...

# %%
df.sort_values("Tanggal", inplace = True)

# %%
df
# Out:
#                Tanggal      Screen Name               Source Hashtags  \
# 0     05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 1     05/05/2021 00:00       pirmann___  Twitter for Android       []
# 2     05/05/2021 00:01       warnapanci  Twitter for Android       []
# 3     05/05/2021 00:01         riskikky   Twitter for iPhone       []
# 4     05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# ...                ...              ...                  ...      ...
# 9163  20/05/2021 16:23     Bams27735590            Instagram       []
# 9164  20/05/2021 16:24       YeshaWally  Twitter for Android       []
# 9165  20/05/2021 16:25       YeshaWally  Twitter for Android       []
# 9166  20/05/2021 16:27  Abiiiii54859988  Twitter for Android       []
# 9167  20/05/2021 16:27         EvaMalca  Twitter for Android       []
#
#      Banyak Retweet                                              Tweet  \
# ...

# %%
df.drop_duplicates(subset ="Tweet", keep = 'first', inplace = True)

# %%
df
# Out:
#                Tanggal      Screen Name               Source Hashtags  \
# 0     05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 1     05/05/2021 00:00       pirmann___  Twitter for Android       []
# 2     05/05/2021 00:01       warnapanci  Twitter for Android       []
# 3     05/05/2021 00:01         riskikky   Twitter for iPhone       []
# 4     05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# ...                ...              ...                  ...      ...
# 9163  20/05/2021 16:23     Bams27735590            Instagram       []
# 9164  20/05/2021 16:24       YeshaWally  Twitter for Android       []
# 9165  20/05/2021 16:25       YeshaWally  Twitter for Android       []
# 9166  20/05/2021 16:27  Abiiiii54859988  Twitter for Android       []
# 9167  20/05/2021 16:27         EvaMalca  Twitter for Android       []
#
#      Banyak Retweet                                              Tweet  \
# ...

# %%
df
# Out:
#                Tanggal      Screen Name               Source Hashtags  \
# 0     05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 1     05/05/2021 00:00       pirmann___  Twitter for Android       []
# 2     05/05/2021 00:01       warnapanci  Twitter for Android       []
# 3     05/05/2021 00:01         riskikky   Twitter for iPhone       []
# 4     05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# ...                ...              ...                  ...      ...
# 9163  20/05/2021 16:23     Bams27735590            Instagram       []
# 9164  20/05/2021 16:24       YeshaWally  Twitter for Android       []
# 9165  20/05/2021 16:25       YeshaWally  Twitter for Android       []
# 9166  20/05/2021 16:27  Abiiiii54859988  Twitter for Android       []
# 9167  20/05/2021 16:27         EvaMalca  Twitter for Android       []
#
#      Banyak Retweet                                              Tweet  \
# ...

# %%
df.replace('',np.nan)
df.dropna(axis="columns", how="any")
df.head(10)
# Out:
#             Tanggal      Screen Name               Source  \
# 0  05/05/2021 00:00        akmal_wii  Twitter for Android
# 1  05/05/2021 00:00       pirmann___  Twitter for Android
# 2  05/05/2021 00:01       warnapanci  Twitter for Android
# 3  05/05/2021 00:01         riskikky   Twitter for iPhone
# 4  05/05/2021 00:01  AriefHi64201710  Twitter for Android
# 5  05/05/2021 00:02      zakira_kiro  Twitter for Android
# 6  05/05/2021 00:02  Istiqom19235191  Twitter for Android
# 7  05/05/2021 00:03    pikiran_tukar      Twitter Web App
# 8  05/05/2021 00:04           AFaryz  Twitter for Android
# 9  05/05/2021 00:05     redywanjames  Twitter for Android
#
#                                             Hashtags Banyak Retweet  \
# 0                                                 []            0 0
# 1                                                 []         1977 0
# 2                                                 []          442 0
# ...

# %%
df
# Out:
#                Tanggal      Screen Name               Source Hashtags  \
# 0     05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 1     05/05/2021 00:00       pirmann___  Twitter for Android       []
# 2     05/05/2021 00:01       warnapanci  Twitter for Android       []
# 3     05/05/2021 00:01         riskikky   Twitter for iPhone       []
# 4     05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# ...                ...              ...                  ...      ...
# 9163  20/05/2021 16:23     Bams27735590            Instagram       []
# 9164  20/05/2021 16:24       YeshaWally  Twitter for Android       []
# 9165  20/05/2021 16:25       YeshaWally  Twitter for Android       []
# 9166  20/05/2021 16:27  Abiiiii54859988  Twitter for Android       []
# 9167  20/05/2021 16:27         EvaMalca  Twitter for Android       []
#
#      Banyak Retweet                                              Tweet  \
# ...

# %%
df.to_csv('Dataset/Label Otomatis/5-20 drop duplicate.csv',encoding='utf8', index=False)
df
# Out:
#                Tanggal      Screen Name               Source Hashtags  \
# 0     05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 1     05/05/2021 00:00       pirmann___  Twitter for Android       []
# 2     05/05/2021 00:01       warnapanci  Twitter for Android       []
# 3     05/05/2021 00:01         riskikky   Twitter for iPhone       []
# 4     05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# ...                ...              ...                  ...      ...
# 9163  20/05/2021 16:23     Bams27735590            Instagram       []
# 9164  20/05/2021 16:24       YeshaWally  Twitter for Android       []
# 9165  20/05/2021 16:25       YeshaWally  Twitter for Android       []
# 9166  20/05/2021 16:27  Abiiiii54859988  Twitter for Android       []
# 9167  20/05/2021 16:27         EvaMalca  Twitter for Android       []
#
#      Banyak Retweet                                              Tweet  \
# ...
