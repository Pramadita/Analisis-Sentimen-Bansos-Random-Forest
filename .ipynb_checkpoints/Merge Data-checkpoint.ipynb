# %%
import numpy as np
import pandas as pd
import nltk 

from datetime import datetime

# %%
data1 = pd.read_csv('Dataset/Pra-Lebaran/Label Ulang/New/All_Label.csv', sep=";")

# %%
def load_data():
    data = pd.concat([data1])
    return data

# %%
tweet_df = load_data()

# %%
tweet_df.head()
# Out:
#             Tanggal                                             Tweets  \
# 0  06/05/2021 07:45  b"@adeweee_ Bansos ga berlaku buat orang yang ...
# 1  06/05/2021 14:25  b"@Bams44421380 @aik_arif Tp hubungan antara a...
# 2  07/05/2021 03:47  b"@bangZhack86 Ada ini, da.\nSurat terbuka kep...
# 3  06/05/2021 06:47  b"@geloraco Ada kata cebong si anak madam bans...
# 4  09/05/2021 13:53  b"@henrysubiakto O gitu pak ?! Jd yg \n- tdk k...
#
#    Sentiment        ID  Screen Name  Banyak Retweet               Source  \
# 0        0.0  1,39E+18      adekiil             0.0  Twitter for Android
# 1        0.0  1,39E+18    ngimpikau             0.0  Twitter for Android
# 2        0.0  1,39E+18  ayah_neisha             0.0  Twitter for Android
# 3        0.0       NaN          NaN             NaN                  NaN
# 4        0.0  1,39E+18    fa_fenani             0.0  Twitter for Android
#
#    Retweet Status Hashtags
# 0             0.0       []
# 1             0.0       []
# ...

# %%
df  = pd.DataFrame(tweet_df[['Tanggal','Tweets', 'Sentiment','ID', 'Screen Name', 'Banyak Retweet', 'Source', 'Retweet Status', 'Hashtags']])

# %%
df
# Out:
#                 Tanggal                                             Tweets  \
# 0      06/05/2021 07:45  b"@adeweee_ Bansos ga berlaku buat orang yang ...
# 1      06/05/2021 14:25  b"@Bams44421380 @aik_arif Tp hubungan antara a...
# 2      07/05/2021 03:47  b"@bangZhack86 Ada ini, da.\nSurat terbuka kep...
# 3      06/05/2021 06:47  b"@geloraco Ada kata cebong si anak madam bans...
# 4      09/05/2021 13:53  b"@henrysubiakto O gitu pak ?! Jd yg \n- tdk k...
# ...                 ...                                                ...
# 18374  12/05/2021 03:19  b'Selama Ramadhan pemerontah udah menyalurkan ...
# 18375  06/05/2021 05:28  b'Seperti diketahui, Kemensos saat ini terus m...
# 18376  10/05/2021 12:52  b'SERMA SUTARYONO,BABINSA KORAMIL 02 BAYAN MEM...
# 18377  07/05/2021 04:09  b'Sertu Warsono babinsa Sribit melaksanakan ba...
# 18378               NaN                                                NaN
#
#        Sentiment        ID      Screen Name  Banyak Retweet  \
# ...

# %%
df.to_csv('Dataset/Pra-Lebaran/Label Ulang/New/All_Label.csv',encoding='utf8', index=False)
df
# Out:
#                  Tanggal                                             Tweets  \
# 0    2021-05-05 23:59:57  b'RT @PutraWadapi: Risma ungkap Data Ganda Pen...
# 1    2021-05-05 23:59:37  b'RT @RicKY_KCh: uang bansos rakyat miskin dip...
# 2    2021-05-05 23:57:25  b'RT @RamliRizal: Menurut Mbak Risma ke KPK, d...
# 3    2021-05-05 23:56:28  b'RT @BudiSetyarso: Para penyidik yg membongka...
# 4    2021-05-05 23:55:57  b'RT @panca66: Perusahaan penyedia paket banso...
# ..                   ...                                                ...
# 855  2021-05-12 00:17:14  b'RT @twitpos: Madam Bansos kemana rimbanya, a...
# 856  2021-05-12 00:14:57  b'Kate\xc2\xb2nye sih benar, harus sama\xc2\xb...
# 857  2021-05-12 00:14:35  b'RT @PutraWadapi: Jokowi Disebut-sebut di Sid...
# 858  2021-05-12 00:11:19  b'kecewa banget sama pemerenta, sekaligus sedi...
# 859  2021-05-12 00:02:17  b'RT @PutraWadapi: Jokowi Disebut-sebut di Sid...
#
# ...
