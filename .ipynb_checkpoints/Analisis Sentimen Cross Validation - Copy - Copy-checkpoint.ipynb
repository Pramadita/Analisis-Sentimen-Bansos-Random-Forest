# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Dataset/Pra-Lebaran/Clean/All_Clean_Label1.csv', sep=',', encoding='utf-8')
data.head()
# Out:
#          ID  Sentiment tweet_clean
# 0  1,39E+18          0          []
# 1  1,39E+18          0          []
# 2  1,39E+18          0          []
# 3  1,39E+18          0          []
# 4  1,39E+18          0          []

# %%
data_clean = pd.read_csv('Dataset/Pra-Lebaran/Clean/All_Clean_Label1.csv', sep=',', encoding='latin1')
data_clean = data_clean.astype({'Sentiment' : 'category'})
data_clean = data_clean.astype({'tweet_clean' : 'string'})
data_clean.dtypes
# Out:
# ID               object
# Sentiment      category
# tweet_clean      string
# dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

tf = TfidfVectorizer()
tvec = CountVectorizer()
X_cVec = tf.fit_transform(data_clean['tweet_clean'].astype('U'))
print(X_cVec)
h_tfidf= TfidfTransformer()
x_tfidf = h_tfidf.fit_transform(X_cVec)
print(x_tfidf)
X = data_clean.tweet_clean
Y = data_clean.Sentiment
# Out:
#   (9, 6209)	0.20932156049770156
#   (9, 2522)	0.1570336408149337
#   (9, 3646)	0.13577076700783627
#   (9, 6884)	0.24831997623490534
#   (9, 2577)	0.16112395967042223
#   (9, 231)	0.28847020274999885
#   (9, 5871)	0.45211573835655733
#   (9, 2197)	0.5769404054999977
#   (9, 1766)	0.2597348955175388
#   (9, 7353)	0.23373616065205438
#   (9, 649)	0.04360681762742065
#   (9, 132)	0.2845824735992268
#   (10, 8412)	0.40724748254639026
#   (10, 765)	0.39094019122497903
#   (10, 1202)	0.40724748254639026
#   (10, 4300)	0.07758058624182512
#   (10, 4152)	0.22809929555277922
#   (10, 421)	0.37039543387197055
#   (10, 8425)	0.2697908590981015
#   (10, 5039)	0.22538689295381512
#   (10, 735)	0.2725185977235805
#   (10, 3360)	0.26312290532232796
#   (10, 196)	0.22430857825497158
#   (10, 649)	0.0531336289011475
#   (11, 2284)	0.26488626982705543
#   :	:
#   (18376, 9116)	0.24941569884007456
#   (18376, 7391)	0.25201971300983467
#   (18376, 3479)	0.24702023801438616
#   (18376, 4627)	0.4682561508886463
#   (18376, 6765)	0.2822941805483383
#   (18376, 2848)	0.19082572046021354
#   (18376, 6335)	0.25802524185580783
#   (18376, 1777)	0.21824781320223013
#   (18376, 8631)	0.10833774724341315
#   (18376, 8795)	0.10511756677450396
#   (18376, 924)	0.1509655625659435
#   (18376, 4422)	0.18944951092736123
#   (18376, 9086)	0.2054090147464787
#   (18376, 649)	0.03953743012552087
#   (18377, 5044)	0.44146713963381945
#   (18377, 3502)	0.42378960063511306
#   (18377, 8472)	0.3712985828477677
#   (18377, 9116)	0.3633496955919247
#   (18377, 3969)	0.3331297430703305
#   (18377, 202)	0.3219715148728651
#   (18377, 9039)	0.19820109866339955
#   (18377, 7290)	0.2736077282591448
#   (18377, 1732)	0.12824694604816358
#   (18377, 4300)	0.08409942594400689
#   (18377, 649)	0.05759827175035374
#   (9, 132)	0.3224088060847104
#   (9, 649)	0.007570061060348194
#   (9, 7353)	0.21749155960184416
#   (9, 1766)	0.13428305165512316
#   (9, 2197)	0.6625558771105909
#   (9, 5871)	0.40687391741183154
#   (9, 231)	0.33127793855529547
#   (9, 2577)	0.10335008733852333
#   (9, 6884)	0.24547875471020247
#   (9, 3646)	0.07338429703471665
#   (9, 2522)	0.0981693680373378
#   (9, 6209)	0.1744289325150983
#   (10, 649)	0.008127403424979876
#   (10, 196)	0.14484537302348133
#   (10, 3360)	0.19931049737098328
#   (10, 735)	0.21379874537785784
#   (10, 5039)	0.14624134564367816
#   (10, 8425)	0.2095401851629362
#   (10, 421)	0.39495181101936905
#   (10, 4152)	0.14978238764160767
#   (10, 4300)	0.01732682445108517
#   (10, 1202)	0.4774519571245361
#   (10, 765)	0.43998057539088153
#   (10, 8412)	0.4774519571245361
#   (11, 649)	0.00780554711463835
#   :	:
#   (18376, 8795)	0.04588268861785721
#   (18376, 8631)	0.04873689545716663
#   (18376, 1777)	0.197787144941828
#   (18376, 6335)	0.2764538531115963
#   (18376, 2848)	0.15120706416135712
#   (18376, 6765)	0.3309040711733447
#   (18376, 4627)	0.4552345818821731
#   (18376, 3479)	0.253374748974233
#   (18376, 7391)	0.2637347065069983
#   (18376, 9116)	0.25831274282935707
#   (18376, 7755)	0.16901936906177242
#   (18376, 4171)	0.088427954581577
#   (18376, 2423)	0.35139600542246463
#   (18376, 3796)	0.3813229944654891
#   (18377, 649)	0.00895605295883594
#   (18377, 4300)	0.0190934237268721
#   (18377, 1732)	0.04440090395877931
#   (18377, 7290)	0.20209448790273218
#   (18377, 9039)	0.10604980224558311
#   (18377, 202)	0.2798547288830854
#   (18377, 3969)	0.29958810621260384
#   (18377, 9116)	0.356407922529351
#   (18377, 8472)	0.3721725441125163
#   (18377, 3502)	0.48483988403339323
#   (18377, 5044)	0.5261317532441551

# %%
# Nama fitur
nama_fitur = tf.get_feature_names()

# Dimensi data
dimensions = X_cVec.get_shape()
print(f"Jumlah artikel = {dimensions[0]}")
print(f"Jumlah fitur   = {dimensions[1]}")
# Out:
# Jumlah artikel = 18378
# Jumlah fitur   = 9130

# %%
content1, content2 = [], []

for n in range(dimensions[0]):
    # Convert sparse matrix row by row 
    row = X_cVec.getrow(n).toarray()[0].ravel()
    # Get top values and its indexes 
    top_ten_indices = row.argsort()[-1]
    top_ten_values = row[row.argsort()[-1]]
    # Identify the highest TFIDF value and word #
    highestTFIDFword = nama_fitur[top_ten_indices]
    highestTFIDFvalue = top_ten_values
    top1word = {'nomor artikel': n+1, 'nilai TFIDF': highestTFIDFvalue,
                'top word': highestTFIDFword}
    content1.append(top1word)
    content2.append(highestTFIDFword)

# Hitung Frekuiensi kata dengan bobot terbesar
content2 = np.asarray(content2)
words, n = np.unique(content2, return_counts=True)

# Convert to DataFrame lalu urutkan secara descending
# lalu pilih 20 kata dengan frekuensi terbesar 
words_data = pd.DataFrame({
    'Kata': words,
    'Banyak': n
}).sort_values(by='Banyak', ascending=False).head(20)
words_data
# Out:
#               Kata  Banyak
# 2250         pasca    2369
# 1375      kelompok    1311
# 1280    kabangsaan     822
# 723        dinasti     576
# 1728         makna     480
# 2549            rp     402
# 608             cs     368
# 2713         sidik     355
# 2143        nyikat     342
# 284          banya     339
# 1020        hadiah     312
# 3170          wawa     270
# 1147          ingk     270
# 3056         tunda     266
# 2749       sjumlah     244
# 2685         serap     243
# 3             abal     234
# 1670  lobstersamin     220
# 3180          weww     193
# 463             bs     182

# %%
# Plotting Barplot
plt.figure(figsize = (10,5))
sns.barplot(x = words_data['Kata'],y = words_data['Banyak'])
for i, v in enumerate(words_data['Banyak'].tolist()):
    plt.text(i-len(str(v))/10-.05, v + 50, str(v),fontsize=10)
plt.title('Kata Dengan Bobot Terbesar',fontsize=20)
plt.xticks(rotation=90)
plt.xlabel('Kata',fontsize=16)
plt.ylabel('Frekuensi',fontsize=16)
plt.show()

# %%
#splitting data
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

kf = KFold(n_splits=10)
X_array = x_tfidf.toarray()
def cross_val(estimator):
    acc = []
    pcs = []
    rec = []
    
    for train_index,test_index in kf.split(X_array, Y):
        X_train, X_test = X_array[train_index], X_array[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        
        model = estimator.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        acc.append(accuracy_score(y_test, y_pred))
        pcs.append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(f1_score(y_test, y_pred, average='macro',zero_division=0))
        
        print(classification_report(y_test, y_pred, zero_division=0))
        print(f'confusion matrix:\n {confusion_matrix(y_test, y_pred)}')
        print('====================================================\n')
        
    print(f'average Accuracy : {np.mean(acc)}')
    print(f'average Precision : {np.mean(pcs)}')
    print(f'average Recall : {np.mean(rec)}')
    print(f'average f1-score : {np.mean(rec)}')
    
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
cross_val(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      1678
#            1       0.81      0.24      0.37       160
#
#     accuracy                           0.93      1838
#    macro avg       0.87      0.62      0.66      1838
# weighted avg       0.92      0.93      0.91      1838
#
# confusion matrix:
#  [[1669    9]
#  [ 122   38]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      1002
#            1       0.98      0.93      0.95       836
#
#     accuracy                           0.96      1838
#    macro avg       0.96      0.96      0.96      1838
# weighted avg       0.96      0.96      0.96      1838
#
# confusion matrix:
#  [[989  13]
#  [ 61 775]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       174
#            1       1.00      1.00      1.00      1664
#
#     accuracy                           1.00      1838
#    macro avg       0.99      1.00      0.99      1838
# weighted avg       1.00      1.00      1.00      1838
#
# confusion matrix:
#  [[ 173    1]
#  [   5 1659]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      1538
#            1       0.82      0.11      0.19       300
#
#     accuracy                           0.85      1838
#    macro avg       0.84      0.55      0.55      1838
# weighted avg       0.85      0.85      0.80      1838
#
# confusion matrix:
#  [[1531    7]
#  [ 268   32]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1702
#            1       0.98      0.43      0.60       136
#
#     accuracy                           0.96      1838
#    macro avg       0.97      0.72      0.79      1838
# weighted avg       0.96      0.96      0.95      1838
#
# confusion matrix:
#  [[1701    1]
#  [  77   59]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1765
#            1       0.86      0.08      0.15        73
#
#     accuracy                           0.96      1838
#    macro avg       0.91      0.54      0.57      1838
# weighted avg       0.96      0.96      0.95      1838
#
# confusion matrix:
#  [[1764    1]
#  [  67    6]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1715
#            1       0.86      0.59      0.70       123
#
#     accuracy                           0.97      1838
#    macro avg       0.91      0.79      0.84      1838
# weighted avg       0.96      0.97      0.96      1838
#
# confusion matrix:
#  [[1703   12]
#  [  51   72]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1787
#            1       0.90      0.18      0.30        51
#
#     accuracy                           0.98      1838
#    macro avg       0.94      0.59      0.64      1838
# weighted avg       0.97      0.98      0.97      1838
#
# confusion matrix:
#  [[1786    1]
#  [  42    9]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      1696
#            1       0.30      0.04      0.07       141
#
#     accuracy                           0.92      1837
#    macro avg       0.61      0.52      0.52      1837
# weighted avg       0.88      0.92      0.89      1837
#
# confusion matrix:
#  [[1682   14]
#  [ 135    6]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1790
#            1       0.87      0.28      0.42        47
#
#     accuracy                           0.98      1837
#    macro avg       0.92      0.64      0.70      1837
# weighted avg       0.98      0.98      0.98      1837
#
# confusion matrix:
#  [[1788    2]
#  [  34   13]]
# ====================================================
#
# average Accuracy : 0.9497768929447468
# average Precision : 0.8924011804725083
# average Recall : 0.7066667382761788
# average f1-score : 0.7066667382761788

# %%
data['prediction'] = rf.predict(X_cVec)
data.head()
# Out:
#          ID  Sentiment tweet_clean  prediction
# 0  1,39E+18          0          []           0
# 1  1,39E+18          0          []           0
# 2  1,39E+18          0          []           0
# 3  1,39E+18          0          []           0
# 4  1,39E+18          0          []           0

# %%
# Plotting Pie
def pct_pie(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n{:d}".format(pct, absolute)

sentimen = data['tweet_clean'].groupby(data['prediction']).count().values

plt.figure(figsize = (8,8))
plt.pie(sentimen, explode=(0,1), labels=['Negatif','Positif'], shadow=True,
        autopct=lambda pct: pct_pie(pct, sentimen),startangle=90)
plt.title('Perbandingan Sentiment',fontsize=18)
plt.axis('equal')
plt.legend(fontsize=11)
plt.show()

# %%
# Hitung Frekuiensi kata dengan bobot terbesar
content1 = np.asarray(content1)

top1word = pd.DataFrame ({'nomor artikel': n+1, 'nilai TFIDF': highestTFIDFvalue,
                'top word': highestTFIDFword}).sort_values(by='top word', ascending=False).head(20)
top1word
# Out:
#       nomor artikel  nilai TFIDF top word
# 0                 2     0.441467    masya
# 2175              3     0.441467    masya
# 2165              4     0.441467    masya
# 2166              2     0.441467    masya
# 2167              2     0.441467    masya
# 2168              2     0.441467    masya
# 2169              2     0.441467    masya
# 2170              2     0.441467    masya
# 2171              5     0.441467    masya
# 2172              2     0.441467    masya
# 2173              2     0.441467    masya
# 2174              3     0.441467    masya
# 2176              2     0.441467    masya
# 2188              2     0.441467    masya
# 2177              2     0.441467    masya
# 2178              2     0.441467    masya
# 2179              2     0.441467    masya
# 2180              2     0.441467    masya
# 2181              2     0.441467    masya
# 2182              2     0.441467    masya

# %%
x = tf.transform(data['tweet_clean'].values)
y = data['Sentiment'].values

# %%
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.2, random_state=2020)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
classifiers = {
    "Random Forest Classifier": RandomForestClassifier()
}
for name in classifiers.keys():
    classifiers[name].fit(x_train, y_train)
    y_pred = classifiers[name].predict(x_valid)
    print(f"Akurasi dari {name} : ",metrics.accuracy_score(y_valid, y_pred))
# Out:
# Akurasi dari Random Forest Classifier :  0.985310119695321

# %%
data['prediction'] = classifiers['Random Forest Classifier'].predict(X_cVec)
data.head()
# Out:
#          ID  Sentiment tweet_clean  prediction
# 0  1,39E+18          0          []           0
# 1  1,39E+18          0          []           0
# 2  1,39E+18          0          []           0
# 3  1,39E+18          0          []           0
# 4  1,39E+18          0          []           0

# %%
# Melihat banyak Tweet perhari berdasarkan sentiment
data['Tanggal'] = pd.to_datetime(data['Tanggal'])
tph = data['tweet_clean'].groupby([data['Tanggal'].dt.date, data['prediction']]).count()
frek = tph.values

# To Data Frame
tanggal = [ i for i, j in tph.index.tolist() ]
senti = [ j for i, j in tph.index.tolist() ]
sent = pd.DataFrame({'Tanggal':tanggal,'Sentiment':senti, 'Frekuensi':frek})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\dita\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tanggal'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-0386e71dc9a8> in <module>
#       1 # Melihat banyak Tweet perhari berdasarkan sentiment
# ----> 2 data['Tanggal'] = pd.to_datetime(data['Tanggal'])
#       3 tph = data['tweet_clean'].groupby([data['Tanggal'].dt.date, data['prediction']]).count()
#       4 frek = tph.values
#       5
#
# c:\users\dita\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\users\dita\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Tanggal'
