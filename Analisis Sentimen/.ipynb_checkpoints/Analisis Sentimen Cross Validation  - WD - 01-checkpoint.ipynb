# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_clean = pd.read_csv('../Dataset/Pra-Lebaran/Clean/All_Clean_Label_WD - 01.csv', sep=';', encoding='latin1')
data_clean = data_clean.astype({'Sentiment' : 'category'})
data_clean = data_clean.astype({'Tweet' : 'string'})
data_clean.dtypes
# Out:
# Tanggal          object
# Screen Name      object
# Source           object
# Hashtags         object
# Sentiment      category
# Tweet            string
# dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

tf = TfidfVectorizer()
tvec = CountVectorizer()
X_cVec = tf.fit_transform(data_clean['Tweet'].astype('U'))
print(X_cVec)
h_tfidf= TfidfTransformer()
x_tfidf = h_tfidf.fit_transform(X_cVec)
print(x_tfidf)
X = data_clean.Tweet
Y = data_clean.Sentiment
# Out:
#   (0, 3202)	0.2812417325794758
#   (0, 6498)	0.22744760406375703
#   (0, 2898)	0.3461588799979681
#   (0, 4275)	0.09061652499787555
#   (0, 636)	0.06209514501439964
#   (0, 4900)	0.42499357229719686
#   (0, 8307)	0.3223971847568216
#   (0, 174)	0.336842421718442
#   (0, 3677)	0.41773395909824046
#   (0, 2856)	0.4058984904341988
#   (1, 2821)	0.3031583835590344
#   (1, 7537)	0.3029695764736709
#   (1, 3769)	0.2656145205654821
#   (1, 530)	0.28744519115908956
#   (1, 8204)	0.29913609343602005
#   (1, 8377)	0.26926137381884807
#   (1, 111)	0.30259373699773945
#   (1, 3931)	0.214505361957762
#   (1, 3366)	0.2864352433232346
#   (1, 1695)	0.303728399264832
#   (1, 7244)	0.30353779115496615
#   (1, 8263)	0.3014801532720304
#   (1, 636)	0.07904078905145177
#   (2, 2821)	0.3031583835590344
#   (2, 7537)	0.3029695764736709
#   :	:
#   (18322, 4771)	0.22833089318788913
#   (18322, 1735)	0.22443061310375373
#   (18322, 7897)	0.1700714888810416
#   (18322, 1652)	0.1978682889631448
#   (18322, 8667)	0.21540611718902122
#   (18322, 1166)	0.20198030030636743
#   (18322, 4794)	0.15232368652221556
#   (18322, 616)	0.11172788570178438
#   (18322, 8772)	0.1618611750157174
#   (18322, 1459)	0.20351420859236297
#   (18322, 1089)	0.16690464385461456
#   (18322, 3402)	0.1658123128814172
#   (18322, 1563)	0.15253366065516516
#   (18322, 3633)	0.15591223694067946
#   (18322, 636)	0.03336106907954496
#   (18323, 2119)	0.5188171385423851
#   (18323, 5187)	0.47185569689074325
#   (18323, 3919)	0.4008057784673916
#   (18323, 5238)	0.4417306413737514
#   (18323, 4763)	0.3538443368157498
#   (18323, 1711)	0.15045698892991569
#   (18323, 636)	0.06757681755373143
#   (18324, 1780)	0.7055006764599631
#   (18324, 1349)	0.6789283662893764
#   (18324, 4306)	0.20328568312149517
#   (0, 2856)	0.4446819822743128
#   (0, 3677)	0.4709927529454716
#   (0, 174)	0.3062444471275042
#   (0, 8307)	0.28054151777051733
#   (0, 4900)	0.48750534776782484
#   (0, 636)	0.010407105375747152
#   (0, 4275)	0.022163047026555083
#   (0, 2898)	0.323419063123529
#   (0, 6498)	0.1396295676659609
#   (0, 3202)	0.21348835464189103
#   (1, 636)	0.021495497073293474
#   (1, 8263)	0.31272486450794645
#   (1, 7244)	0.3170082006825636
#   (1, 1695)	0.3174064595326331
#   (1, 3366)	0.28229154085333813
#   (1, 3931)	0.15831470774400266
#   (1, 111)	0.31503936830905876
#   (1, 8377)	0.24945549376347737
#   (1, 8204)	0.3078807909702557
#   (1, 530)	0.2842857252764135
#   (1, 3769)	0.24274404511024733
#   (1, 7537)	0.3158224497093443
#   (1, 2821)	0.3162162060536194
#   (2, 636)	0.021495497073293474
#   (2, 8263)	0.31272486450794645
#   :	:
#   (18322, 1166)	0.18374170611578455
#   (18322, 8667)	0.20898050884906633
#   (18322, 1652)	0.17633645842114892
#   (18322, 7897)	0.13027249921881284
#   (18322, 1735)	0.22685790089429675
#   (18322, 4771)	0.23481134089160133
#   (18322, 5815)	0.25638564210941406
#   (18322, 6630)	0.2722678005743619
#   (18322, 6648)	0.25638564210941406
#   (18322, 2533)	0.20898050884906633
#   (18322, 3249)	0.2722678005743619
#   (18322, 2575)	0.25638564210941406
#   (18322, 5599)	0.295462789594893
#   (18322, 6914)	0.295462789594893
#   (18322, 6780)	0.295462789594893
#   (18323, 636)	0.010157693171456815
#   (18323, 1711)	0.0503528841750732
#   (18323, 4763)	0.2784993063988716
#   (18323, 5238)	0.4340249254460331
#   (18323, 3919)	0.3573284272092206
#   (18323, 5187)	0.4952426343471391
#   (18323, 2119)	0.5987261786365197
#   (18324, 4306)	0.06080417289131684
#   (18324, 1349)	0.6782154935570116
#   (18324, 1780)	0.7323432233988528

# %%
# Nama fitur
nama_fitur = tf.get_feature_names()

# Dimensi data
dimensions = X_cVec.get_shape()
print(f"Jumlah artikel = {dimensions[0]}")
print(f"Jumlah fitur   = {dimensions[1]}")
# Out:
# Jumlah artikel = 18325
# Jumlah fitur   = 9127

# %%
content1, content2 = [], []

for n in range(dimensions[0]):
    # Convert sparse matrix row by row 
    row = X_cVec.getrow(n).toarray()[0].ravel()
    # Get top values and its indexes 
    top_ten_indices = row.argsort()[-1]
    top_ten_values = row[row.argsort()[-1]]
    # Identify the highest TFIDF value and word #
    highestTFIDFword = nama_fitur[top_ten_indices]
    highestTFIDFvalue = top_ten_values
    top1word = {'nomor artikel': n+1, 'nilai TFIDF': highestTFIDFvalue,
                'top word': highestTFIDFword}
    content1.append(top1word)
    content2.append(highestTFIDFword)

# Hitung Frekuiensi kata dengan bobot terbesar
content2 = np.asarray(content2)
words, n = np.unique(content2, return_counts=True)

# Convert to DataFrame lalu urutkan secara descending
# lalu pilih 20 kata dengan frekuensi terbesar 
words_data = pd.DataFrame({
    'Kata': words,
    'Banyak': n
}).sort_values(by='Banyak', ascending=False).head(10)
words_data
# Out:
#             Kata  Banyak
# 1945     mukakpk    2369
# 1396    kelompok    1311
# 1301  kabangsaan     822
# 728      dinasti     576
# 1742       makna     480
# 442       bodong     408
# 1858       merah     368
# 2790       sidik     355
# 1493      komisi     342
# 633        dakwa     312

# %%
# Plotting Barplot
plt.figure(figsize = (10,5))
sns.barplot(x = words_data['Kata'],y = words_data['Banyak'])
for i, v in enumerate(words_data['Banyak'].tolist()):
    plt.text(i-len(str(v))/10-.05, v + 50, str(v),fontsize=10)
plt.title('Kata Dengan Bobot Terbesar',fontsize=10)
plt.xticks(rotation=90)
plt.xlabel('Kata',fontsize=16)
plt.ylabel('Frekuensi',fontsize=16)
plt.show()

# %%
#splitting data
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

kf = KFold(n_splits=10)
X_array = x_tfidf.toarray()
def cross_val(estimator):
    acc = []
    pcs = []
    rec = []
    
    for train_index,test_index in kf.split(X_array, Y):
        X_train, X_test = X_array[train_index], X_array[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        
        model = estimator.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        acc.append(accuracy_score(y_test, y_pred))
        pcs.append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(f1_score(y_test, y_pred, average='macro',zero_division=0))
        
        print(classification_report(y_test, y_pred, zero_division=0))
        print(f'confusion matrix:\n {confusion_matrix(y_test, y_pred)}')
        print('====================================================\n')
        
    print(f'average Accuracy : {np.mean(acc)}')
    print(f'average Precision : {np.mean(pcs)}')
    print(f'average Recall : {np.mean(rec)}')
    print(f'average f1-score : {np.mean(rec)}')
    
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
cross_val(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1803
#            1       0.71      0.40      0.51        30
#
#     accuracy                           0.99      1833
#    macro avg       0.85      0.70      0.75      1833
# weighted avg       0.99      0.99      0.99      1833
#
# confusion matrix:
#  [[1798    5]
#  [  18   12]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1801
#            1       0.67      0.25      0.36        32
#
#     accuracy                           0.98      1833
#    macro avg       0.83      0.62      0.68      1833
# weighted avg       0.98      0.98      0.98      1833
#
# confusion matrix:
#  [[1797    4]
#  [  24    8]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1771
#            1       0.91      0.50      0.65        62
#
#     accuracy                           0.98      1833
#    macro avg       0.95      0.75      0.82      1833
# weighted avg       0.98      0.98      0.98      1833
#
# confusion matrix:
#  [[1768    3]
#  [  31   31]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1740
#            1       0.92      0.74      0.82        93
#
#     accuracy                           0.98      1833
#    macro avg       0.95      0.87      0.91      1833
# weighted avg       0.98      0.98      0.98      1833
#
# confusion matrix:
#  [[1734    6]
#  [  24   69]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1627
#            1       0.97      0.80      0.87       206
#
#     accuracy                           0.97      1833
#    macro avg       0.97      0.90      0.93      1833
# weighted avg       0.97      0.97      0.97      1833
#
# confusion matrix:
#  [[1622    5]
#  [  42  164]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      1607
#            1       0.93      0.69      0.80       225
#
#     accuracy                           0.96      1832
#    macro avg       0.95      0.84      0.89      1832
# weighted avg       0.96      0.96      0.95      1832
#
# confusion matrix:
#  [[1596   11]
#  [  69  156]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1757
#            1       0.95      0.75      0.84        75
#
#     accuracy                           0.99      1832
#    macro avg       0.97      0.87      0.91      1832
# weighted avg       0.99      0.99      0.99      1832
#
# confusion matrix:
#  [[1754    3]
#  [  19   56]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1797
#            1       0.96      0.66      0.78        35
#
#     accuracy                           0.99      1832
#    macro avg       0.98      0.83      0.89      1832
# weighted avg       0.99      0.99      0.99      1832
#
# confusion matrix:
#  [[1796    1]
#  [  12   23]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1782
#            1       0.83      0.30      0.44        50
#
#     accuracy                           0.98      1832
#    macro avg       0.91      0.65      0.72      1832
# weighted avg       0.98      0.98      0.97      1832
#
# confusion matrix:
#  [[1779    3]
#  [  35   15]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89      1437
#            1       0.89      0.12      0.22       395
#
#     accuracy                           0.81      1832
#    macro avg       0.85      0.56      0.55      1832
# weighted avg       0.82      0.81      0.75      1832
#
# confusion matrix:
#  [[1431    6]
#  [ 346   49]]
# ====================================================
#
# average Accuracy : 0.9635965272764956
# average Precision : 0.9194286483804414
# average Recall : 0.7816695512262843
# average f1-score : 0.7816695512262843

# %%
data['prediction'] = rf.predict(X_cVec)
data.head()
# Out:
#             Tanggal      Screen Name               Source Hashtags  Sentiment  \
# 0  05/05/2021 00:00        akmal_wii  Twitter for Android       []          0
# 1  05/05/2021 00:00   radityapinaruh  Twitter for Android       []          0
# 2  05/05/2021 00:00       pirmann___  Twitter for Android       []          0
# 3  05/05/2021 00:01     Billi_Wijaya  Twitter for Android       []          0
# 4  05/05/2021 00:01  AriefHi64201710  Twitter for Android       []          0
#
#                                                Tweet  prediction
# 0  halah kaget alat test manipulas bansos korupsi...           0
# 1  terang saksi dakwa  jabat kemensos ajak tim te...           0
# 2  terang saksi dakwa  jabat kemensos ajak tim te...           0
# 3  hadap kpk meg korupsi  bansos ekspor benih lob...           0
# 4  hadap kpk meg korupsi  bansos ekspor benih lob...           0

# %%
data.to_csv('Dataset/Pra-Lebaran/Predict/Predict_All_Clean_Label_WD - 01.csv',encoding='utf8', index=False)
data.head()
# Out:
#             Tanggal      Screen Name               Source Hashtags  Sentiment  \
# 0  05/05/2021 00:00        akmal_wii  Twitter for Android       []          0
# 1  05/05/2021 00:00   radityapinaruh  Twitter for Android       []          0
# 2  05/05/2021 00:00       pirmann___  Twitter for Android       []          0
# 3  05/05/2021 00:01     Billi_Wijaya  Twitter for Android       []          0
# 4  05/05/2021 00:01  AriefHi64201710  Twitter for Android       []          0
#
#                                                Tweet  prediction
# 0  halah kaget alat test manipulas bansos korupsi...           0
# 1  terang saksi dakwa  jabat kemensos ajak tim te...           0
# 2  terang saksi dakwa  jabat kemensos ajak tim te...           0
# 3  hadap kpk meg korupsi  bansos ekspor benih lob...           0
# 4  hadap kpk meg korupsi  bansos ekspor benih lob...           0

# %%
# Plotting Pie
def pct_pie(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n{:d}".format(pct, absolute)

sentimen = data['Tweet'].groupby(data['prediction']).count().values

plt.figure(figsize = (8,8))
plt.pie(sentimen, explode=(0,1), labels=['Negatif','Positif'], shadow=True,
        autopct=lambda pct: pct_pie(pct, sentimen),startangle=90)
plt.title('Perbandingan Sentiment',fontsize=18)
plt.axis('equal')
plt.legend(fontsize=11)
plt.show()

# %%
# Melihat banyak Tweet perhari berdasarkan sentiment
data['Tanggal'] = pd.to_datetime(data['Tanggal'])
tph = data['Tweet'].groupby([data['Tanggal'].dt.date, data['prediction']]).count()
frek = tph.values

# To Data Frame
tanggal = [ i for i, j in tph.index.tolist() ]
senti = [ j for i, j in tph.index.tolist() ]
sent = pd.DataFrame({'Tanggal':tanggal,'Sentiment':senti, 'Frekuensi':frek})

# %%
# Plotting line
plt.figure(figsize = (10,5))
sns.lineplot(x='Tanggal',y='Frekuensi',hue='Sentiment',data=sent)
plt.title('Banyak Tweet per Hari',fontsize=20)
plt.xticks(rotation=45)
plt.xlabel('Tanggal',fontsize=16)
plt.ylabel('Frekuensi',fontsize=16)
plt.legend(['Negatif','Positif'])
plt.show()
