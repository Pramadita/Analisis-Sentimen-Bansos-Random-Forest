# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../Dataset/All-Pra & Pasca ND Clean.csv', sep=',', encoding='utf-8')
data.head()
# Out:
#             Tanggal      Screen Name               Source Hashtags  \
# 0  05/05/2021 00:00       pirmann___  Twitter for Android       []
# 1  05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 2  05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# 3  05/05/2021 00:01       warnapanci  Twitter for Android       []
# 4  05/05/2021 00:01         riskikky   Twitter for iPhone       []
#
#    Banyak Retweet             Source.1  Dif  Sentiment  \
# 0          1977.0  Twitter for Android    5          1
# 1             0.0  Twitter for Android    5          0
# 2           467.0  Twitter for Android    5          0
# 3           442.0  Twitter for Android    5          0
# 4          1730.0   Twitter for iPhone    5          0
#
#                                                Tweet
# 0  terang saksi dakwa jabat kemensos ajak tim tek...
# 1  halah kaget alat test manipulasi bansos korups...
# 2  hadap kpk mega korupsi bansos ekspor benih lob...
# 3    tangan sidik nama edar media singkir kpk sajaea
# 4  usaha sedia paket bansos fiktif emang laku kor...

# %%
data_clean = pd.read_csv('../Dataset/All-Pra & Pasca ND Clean.csv', sep=',', encoding='latin1')
data_clean = data_clean.astype({'Sentiment' : 'category'})
data_clean = data_clean.astype({'Tweet' : 'string'})
data_clean.dtypes
# Out:
# Tanggal             object
# Screen Name         object
# Source              object
# Hashtags            object
# Banyak Retweet     float64
# Source.1            object
# Dif                  int64
# Sentiment         category
# Tweet               string
# dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

tf = TfidfVectorizer()
tvec = CountVectorizer()
X_cVec = tf.fit_transform(data_clean['Tweet'].astype('U'))
print(X_cVec)
h_tfidf= TfidfTransformer()
x_tfidf = h_tfidf.fit_transform(X_cVec)
print(x_tfidf)
X = data_clean.Tweet
Y = data_clean.Sentiment
# Out:
#   (0, 6040)	0.3084921698438383
#   (0, 4560)	0.32488496353747087
#   (0, 11529)	0.33651583575989813
#   (0, 5932)	0.24843863207320582
#   (0, 922)	0.04500521344766306
#   (0, 764)	0.21782954455518772
#   (0, 12520)	0.33028358484210185
#   (0, 12778)	0.2839863394294449
#   (0, 158)	0.3158633581573539
#   (0, 6190)	0.18445200510203638
#   (0, 5361)	0.20084479879566894
#   (0, 2477)	0.2652146476298653
#   (0, 11129)	0.2507944209451172
#   (0, 12601)	0.27881808686117704
#   (1, 5105)	0.24798028067015665
#   (1, 10068)	0.23039459583721303
#   (1, 4675)	0.32340557369124934
#   (1, 6704)	0.12482545545974899
#   (1, 7685)	0.43275189947209775
#   (1, 12686)	0.3325889727873379
#   (1, 253)	0.331688286245512
#   (1, 5798)	0.41821928001142367
#   (1, 4610)	0.422652925780913
#   (1, 922)	0.06165986368042402
#   (2, 12334)	0.4808633347517453
#   :	:
#   (9090, 9649)	0.5852699052868526
#   (9090, 5347)	0.3452863551066375
#   (9090, 2292)	0.3421449394416766
#   (9090, 2500)	0.204723563219043
#   (9090, 922)	0.07225608443208538
#   (9091, 10157)	0.26558338681125326
#   (9091, 7432)	0.26558338681125326
#   (9091, 2387)	0.25415444334446463
#   (9091, 8526)	0.22650757100186794
#   (9091, 3871)	0.20364968406829065
#   (9091, 2846)	0.20212567817247507
#   (9091, 8841)	0.610949052204872
#   (9091, 7546)	0.16304986236308974
#   (9091, 12458)	0.13986421309875116
#   (9091, 2553)	0.17115882680099376
#   (9091, 8835)	0.1943900601574904
#   (9091, 1514)	0.13858999647472622
#   (9091, 6024)	0.14426365881511094
#   (9091, 5849)	0.12191828132498853
#   (9091, 6027)	0.1547560628835694
#   (9091, 4458)	0.18925091816054418
#   (9091, 5730)	0.13812663410325463
#   (9091, 8327)	0.188326663461839
#   (9091, 6704)	0.06352088440443113
#   (9091, 922)	0.0313773265141433
#   (0, 12601)	0.26636747931737914
#   (0, 11129)	0.21551378651380038
#   (0, 2477)	0.24100959197887845
#   (0, 5361)	0.13821669180426097
#   (0, 6190)	0.11657517506965637
#   (0, 158)	0.34185175338038887
#   (0, 12778)	0.2763339306085999
#   (0, 12520)	0.3737776201215758
#   (0, 764)	0.1625821573260037
#   (0, 922)	0.006940087829541274
#   (0, 5932)	0.2114840280857109
#   (0, 11529)	0.3880166191078169
#   (0, 4560)	0.3616583847511114
#   (0, 6040)	0.32608258528243295
#   (1, 922)	0.01017164399078134
#   (1, 4610)	0.4779184429004174
#   (1, 5798)	0.46794426706336156
#   (1, 253)	0.2943379764387197
#   (1, 12686)	0.29593867328546736
#   (1, 7685)	0.5010303065918883
#   (1, 6704)	0.04168620401439993
#   (1, 4675)	0.2798214687138683
#   (1, 10068)	0.14201381913348485
#   (1, 5105)	0.16452061539496912
#   (2, 922)	0.007801825260346576
#   :	:
#   (9090, 2500)	0.07824171544368232
#   (9090, 2292)	0.21853597591438545
#   (9090, 5347)	0.22256738995592373
#   (9090, 9649)	0.6394625075923666
#   (9090, 4215)	0.6982669432202775
#   (9091, 922)	0.004719493533930713
#   (9091, 6704)	0.019341786881096338
#   (9091, 8327)	0.17001496316923742
#   (9091, 5730)	0.09145730069017433
#   (9091, 4458)	0.171687830072386
#   (9091, 6027)	0.11480448801670541
#   (9091, 5849)	0.071252676888007
#   (9091, 6024)	0.09976481613360293
#   (9091, 1514)	0.09207193888562668
#   (9091, 8835)	0.1811388597903215
#   (9091, 2553)	0.14043072025075695
#   (9091, 12458)	0.09377276758696763
#   (9091, 7546)	0.12743959846272596
#   (9091, 8841)	0.5964200810555605
#   (9091, 2846)	0.19584230025155624
#   (9091, 3871)	0.19880669368518683
#   (9091, 8526)	0.24593988581229737
#   (9091, 2387)	0.3096413376691525
#   (9091, 7432)	0.33811569526247215
#   (9091, 10157)	0.33811569526247215

# %%
# Nama fitur
nama_fitur = tf.get_feature_names()

# Dimensi data
dimensions = X_cVec.get_shape()
print(f"Jumlah artikel = {dimensions[0]}")
print(f"Jumlah fitur   = {dimensions[1]}")
# Out:
# Jumlah artikel = 9092
# Jumlah fitur   = 13905

# %%
content1, content2 = [], []

for n in range(dimensions[0]):
    # Convert sparse matrix row by row 
    row = X_cVec.getrow(n).toarray()[0].ravel()
    # Get top values and its indexes 
    top_ten_indices = row.argsort()[-1]
    top_ten_values = row[row.argsort()[-1]]
    # Identify the highest TFIDF value and word #
    highestTFIDFword = nama_fitur[top_ten_indices]
    highestTFIDFvalue = top_ten_values
    top1word = {'nomor artikel': n+1, 'nilai TFIDF': highestTFIDFvalue,
                'top word': highestTFIDFword}
    content1.append(top1word)
    content2.append(highestTFIDFword)

# Hitung Frekuiensi kata dengan bobot terbesar
content2 = np.asarray(content2)
words, n = np.unique(content2, return_counts=True)

# Convert to DataFrame lalu urutkan secara descending
# lalu pilih 20 kata dengan frekuensi terbesar 
words_data = pd.DataFrame({
    'Kata': words,
    'Banyak': n
}).sort_values(by='Banyak', ascending=False).head(20)
words_data
# Out:
#          Kata  Banyak
# 3559   miskin      33
# 5679     urus      31
# 5092   sosial      25
# 4884  semayam      24
# 3192       lu      24
# 952     cilik      22
# 3291   maling      20
# 2472    kabar      20
# 3897    nilai      20
# 3168      loe      19
# 1095     data      19
# 3159       lo      17
# 4204     pdip      15
# 4293  percaya      15
# 710       blt      14
# 1413     duta      14
# 5510  triliun      13
# 4072      org      13
# 4370      pkh      12
# 1881       gk      12

# %%
# Plotting Barplot
plt.figure(figsize = (10,5))
sns.barplot(x = words_data['Kata'],y = words_data['Banyak'])
for i, v in enumerate(words_data['Banyak'].tolist()):
    plt.text(i-len(str(v))/10-.05, v + 5, str(v),fontsize=10)
plt.title('Kata Dengan Bobot Terbesar',fontsize=20)
plt.xticks(rotation=90)
plt.xlabel('Kata',fontsize=16)
plt.ylabel('Frekuensi',fontsize=16)
plt.show()

# %%
#splitting data
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

kf = KFold(n_splits=10)
X_array = x_tfidf.toarray()
def cross_val(estimator):
    acc = []
    pcs = []
    rec = []
    
    for train_index,test_index in kf.split(X_array, Y):
        X_train, X_test = X_array[train_index], X_array[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        
        model = estimator.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        acc.append(accuracy_score(y_test, y_pred))
        pcs.append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(f1_score(y_test, y_pred, average='macro',zero_division=0))
        
        print(classification_report(y_test, y_pred, zero_division=0))
        print(f'confusion matrix:\n {confusion_matrix(y_test, y_pred)}')
        print('====================================================\n')
        
    print(f'average Accuracy : {np.mean(acc)}')
    print(f'average Precision : {np.mean(pcs)}')
    print(f'average Recall : {np.mean(rec)}')
    print(f'average f1-score : {np.mean(rec)}')
    
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
cross_val(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       428
#            1       0.38      0.11      0.17        27
#
#     accuracy                           0.94       455
#    macro avg       0.66      0.55      0.57       455
# weighted avg       0.91      0.94      0.92       455
#
# confusion matrix:
#  [[423   5]
#  [ 24   3]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       420
#            1       0.65      0.32      0.43        34
#
#     accuracy                           0.94       454
#    macro avg       0.80      0.65      0.70       454
# weighted avg       0.92      0.94      0.93       454
#
# confusion matrix:
#  [[414   6]
#  [ 23  11]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       395
#            1       0.92      0.19      0.31        59
#
#     accuracy                           0.89       454
#    macro avg       0.90      0.59      0.63       454
# weighted avg       0.89      0.89      0.86       454
#
# confusion matrix:
#  [[394   1]
#  [ 48  11]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       396
#            1       0.91      0.52      0.66        58
#
#     accuracy                           0.93       454
#    macro avg       0.92      0.75      0.81       454
# weighted avg       0.93      0.93      0.92       454
#
# confusion matrix:
#  [[393   3]
#  [ 28  30]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       407
#            1       0.90      0.57      0.70        47
#
#     accuracy                           0.95       454
#    macro avg       0.93      0.78      0.84       454
# weighted avg       0.95      0.95      0.94       454
#
# confusion matrix:
#  [[404   3]
#  [ 20  27]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       382
#            1       0.83      0.35      0.49        72
#
#     accuracy                           0.89       454
#    macro avg       0.86      0.67      0.71       454
# weighted avg       0.88      0.89      0.86       454
#
# confusion matrix:
#  [[377   5]
#  [ 47  25]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       420
#            1       0.81      0.38      0.52        34
#
#     accuracy                           0.95       454
#    macro avg       0.88      0.69      0.75       454
# weighted avg       0.94      0.95      0.94       454
#
# confusion matrix:
#  [[417   3]
#  [ 21  13]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       406
#            1       0.82      0.29      0.43        48
#
#     accuracy                           0.92       454
#    macro avg       0.87      0.64      0.69       454
# weighted avg       0.91      0.92      0.90       454
#
# confusion matrix:
#  [[403   3]
#  [ 34  14]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       416
#            1       0.87      0.34      0.49        38
#
#     accuracy                           0.94       454
#    macro avg       0.90      0.67      0.73       454
# weighted avg       0.94      0.94      0.93       454
#
# confusion matrix:
#  [[414   2]
#  [ 25  13]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       408
#            1       1.00      0.15      0.26        46
#
#     accuracy                           0.91       454
#    macro avg       0.96      0.58      0.61       454
# weighted avg       0.92      0.91      0.88       454
#
# confusion matrix:
#  [[408   0]
#  [ 39   7]]
# ====================================================
#
# average Accuracy : 0.9251241709832019
# average Precision : 0.8687227075458029
# average Recall : 0.6804175267572793
# average f1-score : 0.6804175267572793

# %%
data['prediction'] = rf.predict(X_cVec)
data.head()
# Out:
#             Tanggal                                              Tweet  \
# 0  05/05/2021 00:00  halah kaget alat test manipulas bansos korupsi...
# 1  05/05/2021 00:00  terang saksi dakwa  jabat kemensos ajak tim te...
# 2  05/05/2021 00:01  hadap kpk meg korupsi  bansos ekspor benih lob...
# 3  05/05/2021 00:01              tangan sidik nam edar med singkir kpk
# 4  05/05/2021 00:01  usah sed paket bansos fiktif emang laku korups...
#
#    Sentiment     Screen Name               Source Hashtags  prediction
# 0          0       akmal_wii  Twitter for Android       []           0
# 1          0  radityapinaruh  Twitter for Android       []           0
# 2          0    Billi_Wijaya  Twitter for Android       []           0
# 3          0      warnapanci  Twitter for Android       []           0
# 4          0        riskikky   Twitter for iPhone       []           0

# %%
data.to_csv('Dataset/Pra-Lebaran/Predict/Predict_All_Clean_Label_ND - 01.csv',encoding='utf8', index=False)
data.head()
# Out:
#             Tanggal                                              Tweet  \
# 0  05/05/2021 00:00  halah kaget alat test manipulas bansos korupsi...
# 1  05/05/2021 00:00  terang saksi dakwa  jabat kemensos ajak tim te...
# 2  05/05/2021 00:01  hadap kpk meg korupsi  bansos ekspor benih lob...
# 3  05/05/2021 00:01              tangan sidik nam edar med singkir kpk
# 4  05/05/2021 00:01  usah sed paket bansos fiktif emang laku korups...
#
#    Sentiment     Screen Name               Source Hashtags  prediction
# 0          0       akmal_wii  Twitter for Android       []           0
# 1          0  radityapinaruh  Twitter for Android       []           0
# 2          0    Billi_Wijaya  Twitter for Android       []           0
# 3          0      warnapanci  Twitter for Android       []           0
# 4          0        riskikky   Twitter for iPhone       []           0

# %%
# Plotting Pie
def pct_pie(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n{:d}".format(pct, absolute)

sentimen = data['Tweet'].groupby(data['prediction']).count().values

plt.figure(figsize = (8,8))
plt.pie(sentimen, explode=(0,1), labels=['Negatif','Positif'], shadow=True,
        autopct=lambda pct: pct_pie(pct, sentimen),startangle=90)
plt.title('Perbandingan Sentiment',fontsize=18)
plt.axis('equal')
plt.legend(fontsize=11)
plt.show()

# %%
# Melihat banyak Tweet perhari berdasarkan sentiment
data['Tanggal'] = pd.to_datetime(data['Tanggal'])
tph = data['Tweet'].groupby([data['Tanggal'].dt.date, data['prediction']]).count()
frek = tph.values

# To Data Frame
tanggal = [ i for i, j in tph.index.tolist() ]
senti = [ j for i, j in tph.index.tolist() ]
sent = pd.DataFrame({'Tanggal':tanggal,'Sentiment':senti, 'Frekuensi':frek})

# %%
# Plotting line
plt.figure(figsize = (10,5))
sns.lineplot(x='Tanggal',y='Frekuensi',hue='Sentiment',data=sent)
plt.title('Banyak Tweet per Hari',fontsize=20)
plt.xticks(rotation=45)
plt.xlabel('Tanggal',fontsize=16)
plt.ylabel('Frekuensi',fontsize=16)
plt.legend(['Negatif','Positif'])
plt.show()

# %%
# Hitung Frekuiensi kata dengan bobot terbesar
content1 = np.asarray(content1)

top1word = pd.DataFrame ({'nomor artikel': n+1, 'nilai TFIDF': highestTFIDFvalue,
                'top word': highestTFIDFword}).sort_values(by='top word', ascending=False).head(20)
top1word
# Out:
#       nomor artikel  nilai TFIDF top word
# 0                 2     0.441467    masya
# 2175              3     0.441467    masya
# 2165              4     0.441467    masya
# 2166              2     0.441467    masya
# 2167              2     0.441467    masya
# 2168              2     0.441467    masya
# 2169              2     0.441467    masya
# 2170              2     0.441467    masya
# 2171              5     0.441467    masya
# 2172              2     0.441467    masya
# 2173              2     0.441467    masya
# 2174              3     0.441467    masya
# 2176              2     0.441467    masya
# 2188              2     0.441467    masya
# 2177              2     0.441467    masya
# 2178              2     0.441467    masya
# 2179              2     0.441467    masya
# 2180              2     0.441467    masya
# 2181              2     0.441467    masya
# 2182              2     0.441467    masya

# %%
x = tf.transform(data['tweet_clean'].values)
y = data['Sentiment'].values

# %%
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.2, random_state=2020)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
classifiers = {
    "Random Forest Classifier": RandomForestClassifier()
}
for name in classifiers.keys():
    classifiers[name].fit(x_train, y_train)
    y_pred = classifiers[name].predict(x_valid)
    print(f"Akurasi dari {name} : ",metrics.accuracy_score(y_valid, y_pred))
# Out:
# Akurasi dari Random Forest Classifier :  0.985310119695321

# %%
data['prediction'] = classifiers['Random Forest Classifier'].predict(X_cVec)
data.head()
# Out:
#          ID  Sentiment tweet_clean  prediction
# 0  1,39E+18          0          []           0
# 1  1,39E+18          0          []           0
# 2  1,39E+18          0          []           0
# 3  1,39E+18          0          []           0
# 4  1,39E+18          0          []           0
