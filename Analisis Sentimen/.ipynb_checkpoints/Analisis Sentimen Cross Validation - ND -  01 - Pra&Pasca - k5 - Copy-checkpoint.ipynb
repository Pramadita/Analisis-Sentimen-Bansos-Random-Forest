# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import Libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import nltk 
from nltk.corpus import stopwords

# %%
data = pd.read_csv('../Dataset/Data Training.csv', sep=';', encoding='utf-8')
data.head()
# Out:
#                                               Tweets  Label
# 0                             bangsa koruptor bansos      1
# 1                  bansos kemensos 2021 cair mei cek      1
# 2                  markas koruptor bansos gimana nih      0
# 3  mahasiswa tagih janji kpk hukum mati koruptor ...      0
# 4         koruptor bansos selamat cebong gembira ria      0

# %%
data_clean = pd.read_csv('../Dataset/Data Training.csv', sep=';', encoding='latin1')
data_clean = data_clean.astype({'Label' : 'category'})
data_clean = data_clean.astype({'Tweets' : 'string'})
data_clean.dtypes
# Out:
# Tweets      string
# Label     category
# dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

tf = TfidfVectorizer()
tvec = CountVectorizer()
X_cVec = tf.fit_transform(data_clean['Tweets'].astype('U'))
print(X_cVec)
h_tfidf= TfidfTransformer()
x_tfidf = h_tfidf.fit_transform(X_cVec)
print(x_tfidf)
X = data_clean.Tweets
Y = data_clean.Label
# Out:
#   (0, 5)	0.30605358774600716
#   (0, 25)	0.5181937691924079
#   (0, 4)	0.7986278351009077
#   (1, 14)	0.5038673456001846
#   (1, 34)	0.37002464012143843
#   (1, 12)	0.37002464012143843
#   (1, 1)	0.42557438190005203
#   (1, 24)	0.5038673456001846
#   (1, 5)	0.19309420745334918
#   (2, 37)	0.5294137970680157
#   (2, 18)	0.5294137970680157
#   (2, 32)	0.5294137970680157
#   (2, 5)	0.20288422826438324
#   (2, 25)	0.3435128590659209
#   (3, 0)	0.34163587424453923
#   (3, 15)	0.34163587424453923
#   (3, 33)	0.34163587424453923
#   (3, 19)	0.34163587424453923
#   (3, 26)	0.34163587424453923
#   (3, 22)	0.34163587424453923
#   (3, 46)	0.34163587424453923
#   (3, 30)	0.34163587424453923
#   (3, 5)	0.13092316648601887
#   (3, 25)	0.22167219020578316
#   (4, 40)	0.46788912337721134
#   :	:
#   (6, 5)	0.19309420745334915
#   (7, 10)	0.2100449181931493
#   (7, 9)	0.2100449181931493
#   (7, 49)	0.2100449181931493
#   (7, 7)	0.2100449181931493
#   (7, 21)	0.2100449181931493
#   (7, 27)	0.2100449181931493
#   (7, 42)	0.2100449181931493
#   (7, 48)	0.2100449181931493
#   (7, 20)	0.2100449181931493
#   (7, 44)	0.2100449181931493
#   (7, 2)	0.2100449181931493
#   (7, 45)	0.2100449181931493
#   (7, 6)	0.4200898363862986
#   (7, 28)	0.2100449181931493
#   (7, 3)	0.4200898363862986
#   (7, 34)	0.15425051046159435
#   (7, 12)	0.15425051046159435
#   (7, 5)	0.16098863068730235
#   (8, 47)	0.45359815590729985
#   (8, 8)	0.45359815590729985
#   (8, 38)	0.45359815590729985
#   (8, 36)	0.45359815590729985
#   (8, 29)	0.38311622397619777
#   (8, 5)	0.173829832756657
#   (0, 4)	0.9133200723007016
#   (0, 25)	0.38451960720095857
#   (0, 5)	0.13413097036352886
#   (1, 5)	0.0832482712536698
#   (1, 24)	0.5668513163980198
#   (1, 1)	0.4043781547952483
#   (1, 12)	0.3057018183241062
#   (1, 34)	0.3057018183241062
#   (1, 14)	0.5668513163980198
#   (2, 25)	0.23539681552502492
#   (2, 5)	0.08211285639422518
#   (2, 32)	0.559120087892711
#   (2, 18)	0.559120087892711
#   (2, 37)	0.559120087892711
#   (3, 25)	0.14703469010701456
#   (3, 5)	0.05128972695233072
#   (3, 30)	0.3492402761377705
#   (3, 46)	0.3492402761377705
#   (3, 22)	0.3492402761377705
#   (3, 26)	0.3492402761377705
#   (3, 19)	0.3492402761377705
#   (3, 33)	0.3492402761377705
#   (3, 15)	0.3492402761377705
#   (3, 0)	0.3492402761377705
#   (4, 25)	0.20546216346370097
#   :	:
#   (6, 11)	0.5668513163980198
#   (7, 5)	0.06309966807169463
#   (7, 12)	0.11585635938544647
#   (7, 34)	0.11585635938544647
#   (7, 3)	0.4296561282543323
#   (7, 28)	0.21482806412716615
#   (7, 6)	0.4296561282543323
#   (7, 45)	0.21482806412716615
#   (7, 2)	0.21482806412716615
#   (7, 44)	0.21482806412716615
#   (7, 20)	0.21482806412716615
#   (7, 48)	0.21482806412716615
#   (7, 42)	0.21482806412716615
#   (7, 27)	0.21482806412716615
#   (7, 21)	0.21482806412716615
#   (7, 7)	0.21482806412716615
#   (7, 49)	0.21482806412716615
#   (7, 9)	0.21482806412716615
#   (7, 10)	0.21482806412716615
#   (8, 5)	0.06899764481315192
#   (8, 29)	0.3351557921213932
#   (8, 36)	0.4698164322418171
#   (8, 38)	0.4698164322418171
#   (8, 8)	0.4698164322418171
#   (8, 47)	0.4698164322418171

# %%
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=1, random_state=0)

clf = clf.fit(x_tfidf,Y)

# %%
clf.estimators_
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=1791095845),
#  DecisionTreeClassifier(max_features='auto', random_state=2135392491)]

# %%
len(clf.estimators_)
# Out:
# 2

# %%
dimensions = X_cVec.get_shape()
plt.figure(figsize=(15,15))
for i in range (len(clf.estimators_)):
    print(tree.plot_tree(clf.estimators_[i], filled=True))
# Out:
# [Text(597.8571428571429, 747.4499999999999, 'X[9] <= 0.107\ngini = 0.444\nsamples = 6\nvalue = [6, 3]'), Text(478.2857142857143, 611.55, 'X[29] <= 0.168\ngini = 0.375\nsamples = 5\nvalue = [6, 2]'), Text(358.7142857142857, 475.65, 'X[40] <= 0.244\ngini = 0.245\nsamples = 4\nvalue = [6, 1]'), Text(239.14285714285714, 339.74999999999994, 'X[1] <= 0.202\ngini = 0.375\nsamples = 3\nvalue = [3, 1]'), Text(119.57142857142857, 203.8499999999999, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'), Text(358.7142857142857, 203.8499999999999, 'X[24] <= 0.283\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'), Text(239.14285714285714, 67.94999999999993, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'), Text(478.2857142857143, 67.94999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'), Text(478.2857142857143, 339.74999999999994, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'), Text(597.8571428571429, 475.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'), Text(717.4285714285714, 611.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]
# [Text(558.0, 713.475, 'X[34] <= 0.058\ngini = 0.444\nsamples = 6\nvalue = [6, 3]'), Text(418.5, 509.625, 'X[17] <= 0.244\ngini = 0.245\nsamples = 4\nvalue = [6, 1]'), Text(279.0, 305.775, 'X[5] <= 0.094\ngini = 0.375\nsamples = 3\nvalue = [3, 1]'), Text(139.5, 101.92499999999995, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'), Text(418.5, 101.92499999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'), Text(558.0, 305.775, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]'), Text(697.5, 509.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
for i in range (len(clf.estimators_)):
    print(tree.export_text(clf.estimators_[i]))
# Out:
# |--- feature_9 <= 0.11
# |   |--- feature_29 <= 0.17
# |   |   |--- feature_40 <= 0.24
# |   |   |   |--- feature_1 <= 0.20
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_1 >  0.20
# |   |   |   |   |--- class: 1.0
# |   |   |--- feature_40 >  0.24
# |   |   |   |--- class: 0.0
# |   |--- feature_29 >  0.17
# |   |   |--- class: 1.0
# |--- feature_9 >  0.11
# |   |--- class: 1.0
#
# |--- feature_34 <= 0.06
# |   |--- class: 0.0
# |--- feature_34 >  0.06
# |   |--- class: 1.0

# %%
# Nama fitur
nama_fitur = tf.get_feature_names()

# Dimensi data
dimensions = X_cVec.get_shape()
print(f"Jumlah artikel = {dimensions[0]}")
print(f"Jumlah fitur   = {dimensions[1]}")
# Out:
# Jumlah artikel = 9
# Jumlah fitur   = 52

# %%
content1, content2 = [], []

for n in range(dimensions[0]):
    # Convert sparse matrix row by row 
    row = X_cVec.getrow(n).toarray()[0].ravel()
    # Get top values and its indexes 
    top_ten_indices = row.argsort()[-1]
    top_ten_values = row[row.argsort()[-1]]
    # Identify the highest TFIDF value and word #
    highestTFIDFword = nama_fitur[top_ten_indices]
    highestTFIDFvalue = top_ten_values
    top1word = {'nomor artikel': n+1, 'nilai TFIDF': highestTFIDFvalue,
                'top word': highestTFIDFword}
    content1.append(top1word)
    content2.append(highestTFIDFword)

# Hitung Frekuiensi kata dengan bobot terbesar
content2 = np.asarray(content2)
words, n = np.unique(content2, return_counts=True)

# Convert to DataFrame lalu urutkan secara descending
# lalu pilih 20 kata dengan frekuensi terbesar 
words_data = pd.DataFrame({
    'Kata': words,
    'Banyak': n
}).sort_values(by='Banyak', ascending=False).head(20)
words_data
# Out:
#       Kata  Banyak
# 0       19       1
# 1   bangsa       1
# 2    bantu       1
# 3     bnpt       1
# 4      cek       1
# 5      nih       1
# 6  selamat       1
# 7  tangkap       1
# 8    upaya       1

# %%
# Plotting Barplot
plt.figure(figsize = (10,5))
sns.barplot(x = words_data['Kata'],y = words_data['Banyak'])
for i, v in enumerate(words_data['Banyak'].tolist()):
    plt.text(i-len(str(v))/10-.05, v + 2, str(v),fontsize=10)
plt.title('Kata Dengan Bobot Terbesar',fontsize=20)
plt.xticks(rotation=90)
plt.xlabel('Kata',fontsize=16)
plt.ylabel('Frekuensi',fontsize=16)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
#splitting data
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

kf = KFold(n_splits=2)
X_array = X_cVec.toarray()
def cross_val(estimator):
    acc = []
    pcs = []
    rec = []
    
    for train_index,test_index in kf.split(X_array, Y):
        X_train, X_test = X_array[train_index], X_array[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        
        model = estimator.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        acc.append(accuracy_score(y_test, y_pred))
        pcs.append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(f1_score(y_test, y_pred, average='macro',zero_division=0))
        
        print(classification_report(y_test, y_pred, zero_division=0))
        print(f'confusion matrix:\n {confusion_matrix(y_test, y_pred)}')
        print('====================================================\n')
        
    print(f'average Accuracy : {np.mean(acc)}')
    print(f'average Precision : {np.mean(pcs)}')
    print(f'average Recall : {np.mean(rec)}')
    print(f'average f1-score : {np.mean(rec)}')
    
cross_val(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         3
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.60         5
#    macro avg       0.30      0.50      0.37         5
# weighted avg       0.36      0.60      0.45         5
#
# confusion matrix:
#  [[3 0]
#  [2 0]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.50         4
#    macro avg       0.25      0.50      0.33         4
# weighted avg       0.25      0.50      0.33         4
#
# confusion matrix:
#  [[2 0]
#  [2 0]]
# ====================================================
#
# average Accuracy : 0.55
# average Precision : 0.275
# average Recall : 0.4270833333333333
# average f1-score : 0.4270833333333333

# %%
data['prediction'] = rf.predict(x_tfidf)
data.head()
# Out:
#             Tanggal      Screen Name               Source Hashtags  \
# 0  05/05/2021 00:00       pirmann___  Twitter for Android       []
# 1  05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 2  05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# 3  05/05/2021 00:01       warnapanci  Twitter for Android       []
# 4  05/05/2021 00:01         riskikky   Twitter for iPhone       []
#
#    Banyak Retweet  Dif  Sentiment  \
# 0          1977.0    5          1
# 1             0.0    5          0
# 2           467.0    5          0
# 3           442.0    5          0
# 4          1730.0    5          0
#
#                                                Tweet  prediction
# 0  terang saksi dakwa jabat kemensos ajak tim tek...           1
# 1  halah kaget alat test manipulasi bansos korups...           0
# 2  hadap kpk mega korupsi bansos ekspor benih lob...           0
# 3         2 tangan sidik nama edar media singkir kpk           0
# 4  usaha sedia paket bansos fiktif emang laku kor...           0

# %%
data.to_csv('../Dataset/All-Pra & Pasca ND Predict.csv',encoding='utf8', index=False)
data.head()
# Out:
#             Tanggal      Screen Name               Source Hashtags  \
# 0  05/05/2021 00:00       pirmann___  Twitter for Android       []
# 1  05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 2  05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# 3  05/05/2021 00:01       warnapanci  Twitter for Android       []
# 4  05/05/2021 00:01         riskikky   Twitter for iPhone       []
#
#    Banyak Retweet  Dif  Sentiment  \
# 0          1977.0    5          1
# 1             0.0    5          0
# 2           467.0    5          0
# 3           442.0    5          0
# 4          1730.0    5          0
#
#                                                Tweet  prediction
# 0  terang saksi dakwa jabat kemensos ajak tim tek...           1
# 1  halah kaget alat test manipulasi bansos korups...           0
# 2  hadap kpk mega korupsi bansos ekspor benih lob...           0
# 3         2 tangan sidik nama edar media singkir kpk           0
# 4  usaha sedia paket bansos fiktif emang laku kor...           0

# %%
data1 = pd.read_csv('../Dataset/All-Pra & Pasca ND Predict.csv', sep=',', encoding='utf-8')
data1.head()
# Out:
#             Tanggal      Screen Name               Source Hashtags  \
# 0  05/05/2021 00:00       pirmann___  Twitter for Android       []
# 1  05/05/2021 00:00        akmal_wii  Twitter for Android       []
# 2  05/05/2021 00:01  AriefHi64201710  Twitter for Android       []
# 3  05/05/2021 00:01       warnapanci  Twitter for Android       []
# 4  05/05/2021 00:01         riskikky   Twitter for iPhone       []
#
#    Banyak Retweet  Dif  Sentiment  \
# 0          1977.0    5          1
# 1             0.0    5          0
# 2           467.0    5          0
# 3           442.0    5          0
# 4          1730.0    5          0
#
#                                                Tweet  prediction
# 0  terang saksi dakwa jabat kemensos ajak tim tek...           1
# 1  halah kaget alat test manipulasi bansos korups...           0
# 2  hadap kpk mega korupsi bansos ekspor benih lob...           0
# 3         2 tangan sidik nama edar media singkir kpk           0
# 4  usaha sedia paket bansos fiktif emang laku kor...           0

# %%
# Plotting Pie
def pct_pie(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n{:d}".format(pct, absolute)

sentimen = data1['Tweet'].groupby(data1['prediction']).count().values

plt.figure(figsize = (8,8))
plt.pie(sentimen, explode=(0,1), labels=['Negatif','Positif'], shadow=True,
        autopct=lambda pct: pct_pie(pct, sentimen),startangle=80)
plt.title('Perbandingan Sentiment',fontsize=18)
plt.axis('equal')
plt.legend(fontsize=11)
plt.show()

# %%
# Create Stopword
with open("../Kamus/Stopword - WC.txt", "r") as f:
    stop_words = f.readline().split()

# %%
index_p = data1['prediction'][data1['Sentiment'] == 1].index
index_n = data1['prediction'][data1['Sentiment'] == 0].index

# %%
# Select Positif & Negatif
positif = x_tfidf[index_p]
negatif = x_tfidf[index_n]

# %%
# Mencari Kata positif & Kata positif Dengan Bobot tertinggi
def finder(words):
    kata, top_kata = {}, {}
    for i in range(words.shape[0]):
        row = words.getrow(i).toarray()[0]
        max_ = max(row)
        for j in range(len(row)):
            if row[j] > 0:
                if nama_fitur[j] not in kata :
                    kata[nama_fitur[j]] = 1
                else :
                    kata[nama_fitur[j]] += 1
                if row[j] == max_:
                    if nama_fitur[j] in top_kata:
                        top_kata[nama_fitur[j]] += 1
                    else :
                        top_kata[nama_fitur[j]] = 1
    return kata, top_kata

# %%
positif, top_positif = finder(positif)
negatif, top_negatif = finder(negatif)

# %%
# Sorting
top_positif = {k: v for k, v in sorted(top_positif.items(), key=lambda item: item[1],reverse=True)}
top_negatif = {k: v for k, v in sorted(top_negatif.items(), key=lambda item: item[1],reverse=True)}

# %%
# WordCloud kata dengan bobot terbesar Positif
w = WordCloud(width=800,height=600,mode='RGBA', stopwords=stop_words, background_color='white',max_words=5000).fit_words(top_positif)
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(w)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
# WordCloud kata dengan bobot terbesar Negatif
w = WordCloud(width=600,height=300,mode='RGBA', stopwords=stop_words, background_color='white', max_words=5000).fit_words(top_negatif)
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(w)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
