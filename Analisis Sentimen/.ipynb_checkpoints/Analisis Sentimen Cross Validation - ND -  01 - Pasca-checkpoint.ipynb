# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import Libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import nltk 
from nltk.corpus import stopwords

# %%
data = pd.read_csv('../Dataset/All-Pasca ND Clean Angka.csv', sep=',', encoding='utf-8')
data.head()
# Out:
#             Tanggal      Screen Name               Source  \
# 0  13/05/2021 00:06          endyseu  Twitter for Android
# 1  13/05/2021 00:08  dellins96364605  Twitter for Android
# 2  13/05/2021 00:21          jdara25  Twitter for Android
# 3  13/05/2021 00:21       nyananan36  Twitter for Android
# 4  13/05/2021 00:30     Yogiesmemed3  Twitter for Android
#
#                                             Hashtags  Banyak Retweet  Dif  \
# 0                                                 []             0.0    4
# 1                                                 []             0.0    5
# 2  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 3  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 4                        ['DukungKebaikanUntukNKRI']             0.0    5
#
#    Sentiment                                              Tweet
# 0          0            bayangno mas mas e dadi bansos sg sasar
# 1          0              ngutang 6000t dapat bansos mie instan
# 2          1   apemberian bansos bukti hadir  9negara masyar...
# 3          1  dukungkebaikanuntuknkri  9pemberian bansos buk...
# 4          0               bansos bukti dukungkebaikanuntuknkri

# %%
data_clean = pd.read_csv('../Dataset/All-Pasca ND Clean Angka.csv', sep=',', encoding='latin1')
data_clean = data_clean.astype({'Sentiment' : 'category'})
data_clean = data_clean.astype({'Tweet' : 'string'})
data_clean.dtypes
# Out:
# Tanggal             object
# Screen Name         object
# Source              object
# Hashtags            object
# Banyak Retweet     float64
# Dif                  int64
# Sentiment         category
# Tweet               string
# dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

tf = TfidfVectorizer()
tvec = CountVectorizer()
X_cVec = tf.fit_transform(data_clean['Tweet'].astype('U'))
print(X_cVec)
h_tfidf= TfidfTransformer()
x_tfidf = h_tfidf.fit_transform(X_cVec)
print(x_tfidf)
X = data_clean.Tweet
Y = data_clean.Sentiment
# Out:
#   (0, 6644)	0.317208900517857
#   (0, 6892)	0.4818632496340585
#   (0, 820)	0.060866508276350866
#   (0, 1690)	0.4437658205465687
#   (0, 4585)	0.4841087640410345
#   (0, 923)	0.4818632496340585
#   (1, 3070)	0.4662715616552989
#   (1, 4799)	0.44285577380453184
#   (1, 1734)	0.3939239506994401
#   (1, 200)	0.5063011153820753
#   (1, 5346)	0.41335536995806993
#   (1, 820)	0.06395337484884343
#   (2, 2151)	0.7028590490556967
#   (2, 4616)	0.20291165005860867
#   (2, 253)	0.39244613341030027
#   (2, 2689)	0.32040165770128937
#   (2, 1362)	0.22731805722161247
#   (2, 586)	0.39244613341030027
#   (2, 820)	0.04957179416645762
#   (3, 5127)	0.20928372950132806
#   (3, 254)	0.4172274760464147
#   (3, 2151)	0.747241677489782
#   (3, 4616)	0.21572467762309366
#   (3, 2689)	0.34063369105495606
#   (3, 1362)	0.24167224798515125
#   :	:
#   (4720, 1643)	0.23215695001502074
#   (4720, 14)	0.21797403040506028
#   (4720, 5031)	0.2086319800830733
#   (4720, 12)	0.0949537363149481
#   (4720, 5208)	0.5882482477097255
#   (4720, 4913)	0.18567949845086132
#   (4720, 2623)	0.1874713910546263
#   (4720, 1912)	0.20492452117950968
#   (4720, 1750)	0.16916763469888285
#   (4720, 4462)	0.16023896221911518
#   (4720, 7379)	0.13622256885918774
#   (4720, 3380)	0.14898134559732956
#   (4720, 5204)	0.18399627408308636
#   (4720, 3544)	0.1551768591004273
#   (4720, 1121)	0.13651637793797344
#   (4720, 3448)	0.12263040980947902
#   (4720, 3541)	0.1396392952753426
#   (4720, 3964)	0.059517832586773435
#   (4720, 820)	0.030746886686285155
#   (4721, 5699)	0.5879908213659117
#   (4721, 2489)	0.5879908213659117
#   (4721, 3150)	0.3633186293031947
#   (4721, 1595)	0.35876988671420573
#   (4721, 1722)	0.2056720683518566
#   (4721, 820)	0.07427200190565646
#   (0, 923)	0.5623606765829002
#   (0, 4585)	0.2838070821695258
#   (0, 1690)	0.47695239392564404
#   (0, 820)	0.008972719910368188
#   (0, 6892)	0.5623606765829002
#   (0, 6644)	0.2437014222422032
#   (1, 820)	0.009039300369205179
#   (1, 5346)	0.3776200550386254
#   (1, 200)	0.5665335731240599
#   (1, 1734)	0.3429514606970013
#   (1, 4799)	0.43344351111401236
#   (1, 3070)	0.48049153362332664
#   (2, 820)	0.006996457734100102
#   (2, 586)	0.4384994454675616
#   (2, 1362)	0.1471217258193793
#   (2, 2689)	0.29227956221335377
#   (2, 253)	0.4384994454675616
#   (2, 4616)	0.11722571881321145
#   (2, 2151)	0.7032592042636062
#   (3, 820)	0.007726808724041324
#   (3, 1362)	0.1624795686275107
#   (3, 2689)	0.3227902400041583
#   (3, 4616)	0.1294627569024314
#   (3, 2151)	0.7766715045360475
#   (3, 254)	0.4842738239112417
#   :	:
#   (4720, 3448)	0.07503141970333235
#   (4720, 1121)	0.09298573298474998
#   (4720, 3544)	0.1201436215968185
#   (4720, 5204)	0.16891369494592287
#   (4720, 3380)	0.11074154794899416
#   (4720, 7379)	0.09258591790030075
#   (4720, 4462)	0.12811000614285706
#   (4720, 1750)	0.14278459660213672
#   (4720, 1912)	0.2095244275649668
#   (4720, 2623)	0.17535445690027932
#   (4720, 4913)	0.17201832461641103
#   (4720, 5208)	0.5755019962488682
#   (4720, 12)	0.04498533112498084
#   (4720, 5031)	0.21717436710775803
#   (4720, 14)	0.23705892672437526
#   (4720, 1643)	0.2689120007229475
#   (4720, 77)	0.29562416611559816
#   (4720, 4408)	0.29562416611559816
#   (4720, 5983)	0.29562416611559816
#   (4721, 820)	0.010521628631715905
#   (4721, 1722)	0.08068324194649686
#   (4721, 1595)	0.24550745036737248
#   (4721, 3150)	0.2517723556339106
#   (4721, 2489)	0.6594377463235643
#   (4721, 5699)	0.6594377463235643

# %%
# Nama fitur
nama_fitur = tf.get_feature_names()

# Dimensi data
dimensions = x_tfidf.get_shape()
print(f"Jumlah artikel = {dimensions[0]}")
print(f"Jumlah fitur   = {dimensions[1]}")
# Out:
# Jumlah artikel = 4722
# Jumlah fitur   = 8228

# %%
content1, content2 = [], []

for n in range(dimensions[0]):
    # Convert sparse matrix row by row 
    row = x_tfidf.getrow(n).toarray()[0].ravel()
    # Get top values and its indexes 
    top_ten_indices = row.argsort()[-1]
    top_ten_values = row[row.argsort()[-1]]
    # Identify the highest TFIDF value and word #
    highestTFIDFword = nama_fitur[top_ten_indices]
    highestTFIDFvalue = top_ten_values
    top1word = {'nomor artikel': n+1, 'nilai TFIDF': highestTFIDFvalue,
                'top word': highestTFIDFword}
    content1.append(top1word)
    content2.append(highestTFIDFword)

# Hitung Frekuiensi kata dengan bobot terbesar
content2 = np.asarray(content2)
words, n = np.unique(content2, return_counts=True)

# Convert to DataFrame lalu urutkan secara descending
# lalu pilih 20 kata dengan frekuensi terbesar 
words_data = pd.DataFrame({
    'Kata': words,
    'Banyak': n
}).sort_values(by='Banyak', ascending=False).head(20)
words_data
# Out:
#                           Kata  Banyak
# 3607  worldstandswithpalestine      12
# 3522                      urus      11
# 1055                   gandeng       9
# 2995                   semayam       8
# 3119                  software       8
# 2861                    royong       7
# 2782                      rame       7
# 3018                   serakah       7
# 583                         bu       7
# 372                 bansosjaga       7
# 863                 distribusi       7
# 3454                     tunai       6
# 1041                     gaduh       6
# 1476                    jreeng       6
# 1060                      gara       6
# 3610                       wow       6
# 2864                     rp100       6
# 2577                      pdip       6
# 2157                    miskin       6
# 2509                      padu       6

# %%
# Plotting Barplot
plt.figure(figsize = (10,5))
sns.barplot(x = words_data['Kata'],y = words_data['Banyak'])
for i, v in enumerate(words_data['Banyak'].tolist()):
    plt.text(i-len(str(v))/10-.05, v + 2, str(v),fontsize=10)
plt.title('Kata Dengan Bobot Terbesar',fontsize=20)
plt.xticks(rotation=90)
plt.xlabel('Kata',fontsize=16)
plt.ylabel('Frekuensi',fontsize=16)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
#splitting data
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

kf = KFold(n_splits=10)
X_array = x_tfidf.toarray()
def cross_val(estimator):
    acc = []
    pcs = []
    rec = []
    
    for train_index,test_index in kf.split(X_array, Y):
        X_train, X_test = X_array[train_index], X_array[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        
        model = estimator.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        acc.append(accuracy_score(y_test, y_pred))
        pcs.append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        rec.append(f1_score(y_test, y_pred, average='macro',zero_division=0))
        
        print(classification_report(y_test, y_pred, zero_division=0))
        print(f'confusion matrix:\n {confusion_matrix(y_test, y_pred)}')
        print('====================================================\n')
        
    print(f'average Accuracy : {np.mean(acc)}')
    print(f'average Precision : {np.mean(pcs)}')
    print(f'average Recall : {np.mean(rec)}')
    print(f'average f1-score : {np.mean(rec)}')
    
cross_val(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       439
#            1       0.86      0.35      0.50        34
#
#     accuracy                           0.95       473
#    macro avg       0.90      0.67      0.74       473
# weighted avg       0.95      0.95      0.94       473
#
# confusion matrix:
#  [[437   2]
#  [ 22  12]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       412
#            1       0.81      0.48      0.60        61
#
#     accuracy                           0.92       473
#    macro avg       0.87      0.73      0.78       473
# weighted avg       0.91      0.92      0.91       473
#
# confusion matrix:
#  [[405   7]
#  [ 32  29]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       365
#            1       0.90      0.62      0.73       107
#
#     accuracy                           0.90       472
#    macro avg       0.90      0.80      0.84       472
# weighted avg       0.90      0.90      0.89       472
#
# confusion matrix:
#  [[358   7]
#  [ 41  66]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89       327
#            1       0.89      0.50      0.64       145
#
#     accuracy                           0.83       472
#    macro avg       0.85      0.74      0.77       472
# weighted avg       0.84      0.83      0.81       472
#
# confusion matrix:
#  [[318   9]
#  [ 72  73]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88       329
#            1       0.88      0.44      0.59       143
#
#     accuracy                           0.81       472
#    macro avg       0.84      0.71      0.73       472
# weighted avg       0.82      0.81      0.79       472
#
# confusion matrix:
#  [[320   9]
#  [ 80  63]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90       364
#            1       0.81      0.36      0.50       108
#
#     accuracy                           0.83       472
#    macro avg       0.82      0.67      0.70       472
# weighted avg       0.83      0.83      0.81       472
#
# confusion matrix:
#  [[355   9]
#  [ 69  39]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89       351
#            1       0.87      0.38      0.53       121
#
#     accuracy                           0.83       472
#    macro avg       0.84      0.68      0.71       472
# weighted avg       0.83      0.83      0.80       472
#
# confusion matrix:
#  [[344   7]
#  [ 75  46]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.93       377
#            1       0.85      0.55      0.67        95
#
#     accuracy                           0.89       472
#    macro avg       0.87      0.76      0.80       472
# weighted avg       0.89      0.89      0.88       472
#
# confusion matrix:
#  [[368   9]
#  [ 43  52]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       325
#            1       0.93      0.66      0.77       147
#
#     accuracy                           0.88       472
#    macro avg       0.90      0.82      0.85       472
# weighted avg       0.89      0.88      0.87       472
#
# confusion matrix:
#  [[318   7]
#  [ 50  97]]
# ====================================================
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92       379
#            1       0.76      0.52      0.62        93
#
#     accuracy                           0.87       472
#    macro avg       0.83      0.74      0.77       472
# weighted avg       0.86      0.87      0.86       472
#
# confusion matrix:
#  [[364  15]
#  [ 45  48]]
# ====================================================
#
# average Accuracy : 0.8707909305908913
# average Precision : 0.8629376532607507
# average Recall : 0.7493084310893943
# average f1-score : 0.7493084310893943

# %%
data['prediction'] = rf.predict(x_tfidf)
data.head()
# Out:
#             Tanggal      Screen Name               Source  \
# 0  13/05/2021 00:06          endyseu  Twitter for Android
# 1  13/05/2021 00:08  dellins96364605  Twitter for Android
# 2  13/05/2021 00:21          jdara25  Twitter for Android
# 3  13/05/2021 00:21       nyananan36  Twitter for Android
# 4  13/05/2021 00:30     Yogiesmemed3  Twitter for Android
#
#                                             Hashtags  Banyak Retweet  Dif  \
# 0                                                 []             0.0    4
# 1                                                 []             0.0    5
# 2  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 3  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 4                        ['DukungKebaikanUntukNKRI']             0.0    5
#
#    Sentiment                                              Tweet  prediction
# 0          0            bayangno mas mas e dadi bansos sg sasar           0
# 1          0              ngutang 6000t dapat bansos mie instan           0
# 2          1   apemberian bansos bukti hadir  9negara masyar...           1
# 3          1  dukungkebaikanuntuknkri  9pemberian bansos buk...           1
# 4          0               bansos bukti dukungkebaikanuntuknkri           0

# %%
data.to_csv('../Dataset/All-Pasca ND Predict.csv',encoding='utf8', index=False)
data.head()
# Out:
#             Tanggal      Screen Name               Source  \
# 0  13/05/2021 00:06          endyseu  Twitter for Android
# 1  13/05/2021 00:08  dellins96364605  Twitter for Android
# 2  13/05/2021 00:21          jdara25  Twitter for Android
# 3  13/05/2021 00:21       nyananan36  Twitter for Android
# 4  13/05/2021 00:30     Yogiesmemed3  Twitter for Android
#
#                                             Hashtags  Banyak Retweet  Dif  \
# 0                                                 []             0.0    4
# 1                                                 []             0.0    5
# 2  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 3  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 4                        ['DukungKebaikanUntukNKRI']             0.0    5
#
#    Sentiment                                              Tweet  prediction
# 0          0            bayangno mas mas e dadi bansos sg sasar           0
# 1          0              ngutang 6000t dapat bansos mie instan           0
# 2          1   apemberian bansos bukti hadir  9negara masyar...           1
# 3          1  dukungkebaikanuntuknkri  9pemberian bansos buk...           1
# 4          0               bansos bukti dukungkebaikanuntuknkri           0

# %%
data1 = pd.read_csv('../Dataset/All-Pasca ND Predict.csv', sep=',', encoding='utf-8')
data1.head()
# Out:
#             Tanggal      Screen Name               Source  \
# 0  13/05/2021 00:06          endyseu  Twitter for Android
# 1  13/05/2021 00:08  dellins96364605  Twitter for Android
# 2  13/05/2021 00:21          jdara25  Twitter for Android
# 3  13/05/2021 00:21       nyananan36  Twitter for Android
# 4  13/05/2021 00:30     Yogiesmemed3  Twitter for Android
#
#                                             Hashtags  Banyak Retweet  Dif  \
# 0                                                 []             0.0    4
# 1                                                 []             0.0    5
# 2  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 3  ['DukungKebaikanUntukNKRI', 'DukungKebaikanUnt...             0.0    4
# 4                        ['DukungKebaikanUntukNKRI']             0.0    5
#
#    Sentiment                                              Tweet  prediction
# 0          0            bayangno mas mas e dadi bansos sg sasar           0
# 1          0              ngutang 6000t dapat bansos mie instan           0
# 2          1   apemberian bansos bukti hadir  9negara masyar...           1
# 3          1  dukungkebaikanuntuknkri  9pemberian bansos buk...           1
# 4          0               bansos bukti dukungkebaikanuntuknkri           0

# %%
# Plotting Pie
def pct_pie(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n{:d}".format(pct, absolute)

sentimen = data1['Tweet'].groupby(data1['prediction']).count().values

plt.figure(figsize = (8,8))
plt.pie(sentimen, explode=(0,1), labels=['Negatif','Positif'], shadow=True,
        autopct=lambda pct: pct_pie(pct, sentimen),startangle=80)
plt.title('Perbandingan Sentiment',fontsize=18)
plt.axis('equal')
plt.legend(fontsize=11)
plt.show()

# %%
# Create Stopword
with open("../Kamus/Stopword - WC - Pasca.txt", "r") as f:
    stop_words = f.readline().split()

# %%
index_p = data1['prediction'][data1['Sentiment'] == 1].index
index_n = data1['prediction'][data1['Sentiment'] == 0].index

# %%
# Select Positif & Negatif
positif = x_tfidf[index_p]
negatif = x_tfidf[index_n]

# %%
# Mencari Kata positif & Kata positif Dengan Bobot tertinggi
def finder(words):
    kata, top_kata = {}, {}
    for i in range(words.shape[0]):
        row = words.getrow(i).toarray()[0]
        max_ = max(row)
        for j in range(len(row)):
            if row[j] > 0:
                if nama_fitur[j] not in kata :
                    kata[nama_fitur[j]] = 1
                else :
                    kata[nama_fitur[j]] += 1
                if row[j] == max_:
                    if nama_fitur[j] in top_kata:
                        top_kata[nama_fitur[j]] += 1
                    else :
                        top_kata[nama_fitur[j]] = 1
    return kata, top_kata

# %%
positif, top_positif = finder(positif)
negatif, top_negatif = finder(negatif)

# %%
# Sorting
top_positif = {k: v for k, v in sorted(top_positif.items(), key=lambda item: item[1],reverse=True)}
top_negatif = {k: v for k, v in sorted(top_negatif.items(), key=lambda item: item[1],reverse=True)}

# %%
# WordCloud kata dengan bobot terbesar Positif
w = WordCloud(width=800,height=600,mode='RGBA', stopwords=stop_words, background_color='white',max_words=5000).fit_words(top_positif)
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(w)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
# WordCloud kata dengan bobot terbesar Negatif
w = WordCloud(width=600,height=300,mode='RGBA', stopwords=stop_words, background_color='white', max_words=5000).fit_words(top_negatif)
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(w)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
